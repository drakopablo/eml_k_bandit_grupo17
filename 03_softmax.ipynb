# %% [markdown]
# <a href="https://colab.research.google.com/github/drakopablo/eml_k_bandit_grupo17/blob/main/03_softmax.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
